# %% [markdown]
# # Chemical Space Network Calculations
#
# **V.F. Scalfani, V.D. Patel, and A.M. Fernandez** \
# v. October 18, 2022
#
# *w/ glucocorticoid_receptor_2034_2.csv dataset*

# %% [markdown]
# ## 1. Import RDKit, Networkx, and other libraries

# %%
# RDKit stuff
from rdkit import Chem
from rdkit import rdBase
from rdkit.Chem import Draw
from rdkit.Chem.Draw import rdMolDraw2D
from rdkit.Chem import rdDepictor
rdDepictor.SetPreferCoordGen(True)
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem import rdFMCS
from rdkit import DataStructs
from rdkit.Chem import rdmolops

# numpy
import numpy as np

# pandas
import pandas as pd

# networkx
import networkx as nx

# matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Print versions of libraries used
print('RDKit version: ',rdBase.rdkitVersion)
print('Numpy version:', np.__version__)
print('Pandas version:', pd.__version__)
print('Networkx version',nx.__version__)
print('MatplotLib version:', mpl.__version__)
# Out:
# RDKit version:  2023.03.1
# Numpy version: 1.24.3
# Pandas version: 2.0.1
# Networkx version 2.8.8
# MatplotLib version: 3.7.1

# %% [markdown]
# ## 2. Load ChEMBL Dataset

# %%
# pd.options.display.max_rows = 30
df = pd.read_csv("Virtualpredictions.csv")
df
# Out:
#         Unnamed: 0 nucleophile SMILES electrophile SMILES 3,3â€™ Catalyst Substituent                              N Catalyst Substituent       ddg        ee  cluster
# 0                0    C=CC[Si](C)(C)C   O=Cc2ccc1ccccc1c2               c2ccc1ccccc1c2                                 NS(=O)(=O)C(F)(F)F  1.194218  0.813590        6
# 1                1    C=CC[Si](C)(C)C   O=Cc2ccc1ccccc1c2               c2ccc1ccccc1c2                          NS(=O)(=O)C(F)(F)C(F)(F)F  1.219084  0.822577        6
# 2                2    C=CC[Si](C)(C)C   O=Cc2ccc1ccccc1c2               c2ccc1ccccc1c2                    NS(=O)(=O)c1c(F)c(F)c(F)c(F)c1F  1.286832  0.844923        6
# 3                3    C=CC[Si](C)(C)C   O=Cc2ccc1ccccc1c2               c2ccc1ccccc1c2            NS(=O)(=O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F  1.191409  0.812546        6
# 4                4    C=CC[Si](C)(C)C   O=Cc2ccc1ccccc1c2               c2ccc1ccccc1c2  NS(=O)(=O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C...  1.191409  0.812546        6
# ...            ...                ...                 ...                          ...                                                ...       ...       ...      ...
# 869755      869755         C1=CCCC=C1              C=CC=O         c3ccc2ccc1ccccc1c2c3                                 NS(=O)(=O)C(F)(F)F  0.805889  0.596744       32
# 869756      869756         C1=CCCC=C1              C=CC=O         c3ccc2ccc1ccccc1c2c3                          NS(=O)(=O)C(F)(F)C(F)(F)F  0.819697  0.607657       32
# 869757      869757         C1=CCCC=C1              C=CC=O         c3ccc2ccc1ccccc1c2c3                    NS(=O)(=O)c1c(F)c(F)c(F)c(F)c1F  1.021453  0.737241       32
# 869758      869758         C1=CCCC=C1              C=CC=O         c3ccc2ccc1ccccc1c2c3            NS(=O)(=O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F  0.810616  0.600514       32
# 869759      869759         C1=CCCC=C1              C=CC=O         c3ccc2ccc1ccccc1c2c3  NS(=O)(=O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C...  0.810616  0.600514       32
#
# [869760 rows x 8 columns]

# %% [markdown]
# # 3. Data Preparation and Checks
#
# Note that we are using the chemical structures as-is (i.e., using ChEMBL's standardization workflow). See supporting manuscript for more details.

# %%
# Create a new dataframe with only Chembl ID, Smiles, and Standard Value (Ki, for this example)
# We are ignoring the Standard relation here for Ki values (i.e., >, <, etc. are treated as =)

"""df1 = df[['Molecule ChEMBL ID','Smiles','Standard Value']].copy()

# drop any rows with NaN (missing Standard Values)
df1.dropna(inplace=True)
df1"""
full_df = pd.read_csv("Virtualpredictions.csv")

len(full_df)
# Out:
# 869760

# %%
# Check for presence of disconnected SMILES notation via string matching 
df2 = full_df[~full_df['3,3â€™ Catalyst Substituent '].str.contains("\.")]
len(full_df) # same as df1
# Out:
# 869760

# %%
# We should double check for disconnected fragments in the event that
# the dot disconnect bond is used with ring-closures
# see: http://www.dalkescientific.com/writings/diary/archive/2004/12/12/library_generation_with_smiles.html

smis = df2['3,3â€™ Catalyst Substituent '].tolist()
num_frags = []
for smi in smis:
    mol = Chem.MolFromSmiles(smi)
    num_frags.append(len(Chem.GetMolFrags(mol))) # returns number of fragments

# %%
# now check that all molecules have only one fragment
all(frag == 1 for frag in num_frags)
# Out:
# True

# %%
df2
# Out:
#         Unnamed: 0 nucleophile SMILES electrophile SMILES 3,3â€™ Catalyst Substituent                              N Catalyst Substituent       ddg        ee  cluster
# 0                0    C=CC[Si](C)(C)C   O=Cc2ccc1ccccc1c2               c2ccc1ccccc1c2                                 NS(=O)(=O)C(F)(F)F  1.194218  0.813590        6
# 1                1    C=CC[Si](C)(C)C   O=Cc2ccc1ccccc1c2               c2ccc1ccccc1c2                          NS(=O)(=O)C(F)(F)C(F)(F)F  1.219084  0.822577        6
# 2                2    C=CC[Si](C)(C)C   O=Cc2ccc1ccccc1c2               c2ccc1ccccc1c2                    NS(=O)(=O)c1c(F)c(F)c(F)c(F)c1F  1.286832  0.844923        6
# 3                3    C=CC[Si](C)(C)C   O=Cc2ccc1ccccc1c2               c2ccc1ccccc1c2            NS(=O)(=O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F  1.191409  0.812546        6
# 4                4    C=CC[Si](C)(C)C   O=Cc2ccc1ccccc1c2               c2ccc1ccccc1c2  NS(=O)(=O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C...  1.191409  0.812546        6
# ...            ...                ...                 ...                          ...                                                ...       ...       ...      ...
# 869755      869755         C1=CCCC=C1              C=CC=O         c3ccc2ccc1ccccc1c2c3                                 NS(=O)(=O)C(F)(F)F  0.805889  0.596744       32
# 869756      869756         C1=CCCC=C1              C=CC=O         c3ccc2ccc1ccccc1c2c3                          NS(=O)(=O)C(F)(F)C(F)(F)F  0.819697  0.607657       32
# 869757      869757         C1=CCCC=C1              C=CC=O         c3ccc2ccc1ccccc1c2c3                    NS(=O)(=O)c1c(F)c(F)c(F)c(F)c1F  1.021453  0.737241       32
# 869758      869758         C1=CCCC=C1              C=CC=O         c3ccc2ccc1ccccc1c2c3            NS(=O)(=O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F  0.810616  0.600514       32
# 869759      869759         C1=CCCC=C1              C=CC=O         c3ccc2ccc1ccccc1c2c3  NS(=O)(=O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C...  0.810616  0.600514       32
#
# [869760 rows x 8 columns]

# %%
# Group by ChEMBLID/Smiles rows, and then take the mean of the standard Ki value to account for duplicates.
# See: Zhang, B. et al. J Comput Aided Mol Des 2015, 29 (10), 937–950. 
# https://doi.org/10.1007/s10822-015-9872-1.
#average_ee_by_name = df2.groupby('Reaction',"Catalyst")['ee'].mean().reset_index()

df3 = df2.groupby("3,3â€™ Catalyst Substituent ")['ee'].mean().reset_index()

# rename the Standard Value Column to Ki
df3.rename(columns={'ee': 'Ki'}, inplace=True)
df3
# Out:
#                          3,3â€™ Catalyst Substituent         Ki
# 0                                    CC(C)(C)c1ccccc1  0.835703
# 1                            CC(C)CCc1cccc(CCC(C)C)c1  0.884771
# 2                             CC3(C)c1ccccc1c2ccccc23  0.897272
# 3                              CCCCCCc1cccc(CCCCCC)c1  0.888566
# 4                                    CCCc1cccc(CCC)c1  0.882770
# 5                                      CCc1cccc(CC)c1  0.884102
# 6                        Cc1cc(C)c2CCc4cccc3CCc1c2c34  0.864035
# 7                        Cc1cc(C)c2ccc4cccc3ccc1c2c34  0.866780
# 8                                        Cc1cc(C)ccc1  0.711824
# 9                                       Cc1cccc(C)c1C  0.792059
# 10                                          Cc1ccccc1  0.743814
# 11  FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F...  0.893865
# 12  FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)...  0.881078
# 13                         FC(F)(F)c1cccc(C(F)(F)F)c1  0.737591
# 14             FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1  0.894233
# 15                             FS(F)(F)(F)(F)c1ccccc1  0.827984
# 16                                     c1cccc2ccccc12  0.829887
# 17                                           c1ccccc1  0.576381
# 18                                     c2ccc1ccccc1c2  0.715895
# 19                                 c2cccc(c1ccccc1)c2  0.753504
# 20                               c3ccc2ccc1ccccc1c2c3  0.773312
# 21                         c4ccc3c1ccccc1C2(CCC2)c3c4  0.886048
# 22                        c4ccc3c1ccccc1C2(CCCC2)c3c4  0.884488
# 23                         c4ccc3c1ccccc1c2ccccc2c3c4  0.894855

# %%
# Double check that all SMILES are unique (different) compounds
# To be on the safe side, we can parse the SMILES as RDKit mol objects
# then write out canonical smiles and check

smis = df3['3,3â€™ Catalyst Substituent '].tolist()
rdkit_can_smiles = []
for smi in smis:
    mol = Chem.MolFromSmiles(smi)       
    rdkit_can_smiles.append(Chem.MolToSmiles(mol, canonical=True)) # default is true
    
set_rdkit_can_smiles = set(rdkit_can_smiles)
len(set_rdkit_can_smiles) == len(rdkit_can_smiles)
# Out:
# False

# %%
# We'll use the original SMILES as unique dictionary keys, so we should verify that the
# ChEMBL SMILES are unique strings too.
set_smis = set(smis)
len(set_smis) == len(smis)
# Out:
# True

# %% [markdown]
# ## 4. Compile Node data

# %%
# We will use pKi for coloring nodes.
from math import log10
"""
# Ki values are in nM units
# 1. convert to M
df3.loc[:,"Ki_M"] = (df3.loc[:,"Ki"] * (10**-9))

# 2. then compute -log10[Ki]
def minuslog(x):
    return -log10(x)

df3.loc[:,"pKi"] = (df3.loc[:,"Ki_M"].apply(minuslog))"""
df3["pKi"] = df3["Ki"]

# %%
# drop Ki and Ki_M columns (no longer needed)
df3.drop(["Ki","Ki"],axis=1,inplace=True)
df3
# Out:
#                          3,3â€™ Catalyst Substituent        pKi
# 0                                    CC(C)(C)c1ccccc1  0.835703
# 1                            CC(C)CCc1cccc(CCC(C)C)c1  0.884771
# 2                             CC3(C)c1ccccc1c2ccccc23  0.897272
# 3                              CCCCCCc1cccc(CCCCCC)c1  0.888566
# 4                                    CCCc1cccc(CCC)c1  0.882770
# 5                                      CCc1cccc(CC)c1  0.884102
# 6                        Cc1cc(C)c2CCc4cccc3CCc1c2c34  0.864035
# 7                        Cc1cc(C)c2ccc4cccc3ccc1c2c34  0.866780
# 8                                        Cc1cc(C)ccc1  0.711824
# 9                                       Cc1cccc(C)c1C  0.792059
# 10                                          Cc1ccccc1  0.743814
# 11  FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F...  0.893865
# 12  FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)...  0.881078
# 13                         FC(F)(F)c1cccc(C(F)(F)F)c1  0.737591
# 14             FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1  0.894233
# 15                             FS(F)(F)(F)(F)c1ccccc1  0.827984
# 16                                     c1cccc2ccccc12  0.829887
# 17                                           c1ccccc1  0.576381
# 18                                     c2ccc1ccccc1c2  0.715895
# 19                                 c2cccc(c1ccccc1)c2  0.753504
# 20                               c3ccc2ccc1ccccc1c2c3  0.773312
# 21                         c4ccc3c1ccccc1C2(CCC2)c3c4  0.886048
# 22                        c4ccc3c1ccccc1C2(CCCC2)c3c4  0.884488
# 23                         c4ccc3c1ccccc1c2ccccc2c3c4  0.894855

# %%
# get the max/min Ki values, which will be used for a color bar later
print(df3.pKi.max())
print(df3.pKi.min())
# Out:
# 0.8972723117853201
# 0.5763813942963912

# %%
# set the dataframe index as Smiles (we already verified they are all unique from eachother)
df4 = df3.set_index('3,3â€™ Catalyst Substituent ')

# %%
pd.set_option("expand_frame_repr", False)
print(df4.head(10)) # view first 10
# Out:
#                                    pKi
# 3,3â€™ Catalyst Substituent
# CC(C)(C)c1ccccc1              0.835703
# CC(C)CCc1cccc(CCC(C)C)c1      0.884771
# CC3(C)c1ccccc1c2ccccc23       0.897272
# CCCCCCc1cccc(CCCCCC)c1        0.888566
# CCCc1cccc(CCC)c1              0.882770
# CCc1cccc(CC)c1                0.884102
# Cc1cc(C)c2CCc4cccc3CCc1c2c34  0.864035
# Cc1cc(C)c2ccc4cccc3ccc1c2c34  0.866780
# Cc1cc(C)ccc1                  0.711824
# Cc1cccc(C)c1C                 0.792059

# %%
# save to a dictionary
node_data = df4.to_dict('index')

# %%
# SMILES are the keys
list(node_data.keys())[0]
# Out:
# 'CC(C)(C)c1ccccc1'

# %%
# ChEMBL ID and pKi are the associated values
list(node_data.values())[0]
# Out:
# {'pKi': 0.8357030625011037}

# %%
# print(node_data)

# %% [markdown]
# ## 5. Compute and Compile Edge Data

# %%
# We first need to create subset pairs of the SMILES
smis = [] # using ChEMBL provided SMILES
for key,value in node_data.items():
    smis.append(key)

from itertools import combinations
smis_subsets = list(combinations(smis,2))
len(smis_subsets)
# Out:
# 276

# %%
# View first 5
smis_subsets[0:5]
# Out:
# [('CC(C)(C)c1ccccc1', 'CC(C)CCc1cccc(CCC(C)C)c1'),
#  ('CC(C)(C)c1ccccc1', 'CC3(C)c1ccccc1c2ccccc23'),
#  ('CC(C)(C)c1ccccc1', 'CCCCCCc1cccc(CCCCCC)c1'),
#  ('CC(C)(C)c1ccccc1', 'CCCc1cccc(CCC)c1'),
#  ('CC(C)(C)c1ccccc1', 'CCc1cccc(CC)c1')]

# %%
# create a dictionary, subsets
subsets = {}
for i, (smi1,smi2) in enumerate(smis_subsets):
    field = {}
    field["smi1"] = smi1
    subsets[i] = field
    
    field["smi2"] = smi2
    subsets[i] = field
len(subsets)
# Out:
# 276

# %%
# get first key
list(subsets)[0]
# Out:
# 0

# %%
# get first value
list(subsets.values())[0]
# Out:
# {'smi1': 'CC(C)(C)c1ccccc1', 'smi2': 'CC(C)CCc1cccc(CCC(C)C)c1'}

# %%
# get smi1
list(subsets.values())[0]['smi1']
# Out:
# 'CC(C)(C)c1ccccc1'

# %%
# add mol objects to our subsets dictionary
for key,value in subsets.items():
    subsets[key].update({"mol1": Chem.MolFromSmiles(value['smi1'])})
    subsets[key].update({"mol2": Chem.MolFromSmiles(value['smi2'])})

# %%
list(subsets.keys())[0]
# Out:
# 0

# %%
list(subsets.values())[0]
# Out:
# {'smi1': 'CC(C)(C)c1ccccc1',
#  'smi2': 'CC(C)CCc1cccc(CCC(C)C)c1',
#  'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119dee0>,
#  'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119df50>}

# %% [markdown]
# ### Compute Tanimoto Similarity (RDKit fingerprint based)

# %%
# compute and add Tanimoto Similarity using default RDKit fingerprints
for key,value in subsets.items():
    fp1 = Chem.RDKFingerprint(value['mol1'])
    fp2 = Chem.RDKFingerprint(value['mol2'])
    tan_sim = round(DataStructs.TanimotoSimilarity(fp1,fp2), 3)
    subsets[key].update({"tan_similarity": tan_sim})

# %%
list(subsets.values())[0]
# Out:
# {'smi1': 'CC(C)(C)c1ccccc1',
#  'smi2': 'CC(C)CCc1cccc(CCC(C)C)c1',
#  'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119dee0>,
#  'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119df50>,
#  'tan_similarity': 0.382}

# %% [markdown]
# ### Compute MCS-based Tanimoto Coefficient (single processor)

# %%
# Add maximum common substructure (MCS)-based Tanimoto Coefficient
# See Vogt, M. et al. J Comput Aided Mol Des 2016, 30 (3), 191–208. 
# https://doi.org/10.1007/s10822-016-9906-3.

############
############

# Compute and add MCS-based similarity
# This may take a very long time...

#############
#############

#def tc_mcs(mol1,mol2):
#    # get maximum common substructure instance
#    mcs = rdFMCS.FindMCS([mol1,mol2],timeout=10) # adding a 10 second timeout for now
    
#    # get number of common bonds
#    mcs_bonds = mcs.numBonds
    
#    # get number of bonds for each
#    # default is only heavy atom bonds
#    mol1_bonds = mol1.GetNumBonds()
#    mol2_bonds = mol2.GetNumBonds()
    
#    # compute MCS-based Tanimoto  
#    tan_mcs = mcs_bonds / (mol1_bonds + mol2_bonds - mcs_bonds)
#    return tan_mcs


# loop through subsets and compute tc_mcs

#for key,value in subsets.items():
#    tan_mcs_value = round(tc_mcs(value['mol1'], value['mol2']), 3)
#    print(key) # to watch progress
#    subsets[key].update({"tan_mcs": tan_mcs_value})

# %% [markdown]
# ### Compute MCS-based Tanimoto Coefficient (multiprocessing)

# %%
# get number of processors
import multiprocessing
print(multiprocessing.cpu_count())
# Out:
# 24

# %%
# From the Python docs, this below is number of usable CPUs (works on Unix/Linux)
# https://docs.python.org/3/library/multiprocessing.html
# we subtracted 2 from total number, so that we can still easily use computer for other tasks
import os
num_cpus = len(os.sched_getaffinity(0)) - 2
num_cpus
# Out:
# 22

# %%
# Add maximum common substructure (MCS)-based Tanimoto Coefficient
# See Vogt, M. et al. J Comput Aided Mol Des 2016, 30 (3), 191–208. 
# https://doi.org/10.1007/s10822-016-9906-3.

############
############

# Compute and add MCS-based similarity

# Here are benchmark times with the 10 second timeout in FindMCS and the 81,000 compound gluco pairs:
    # Intel Core i9-9980HK (2.4 GHz x 16) Ubuntu laptop using 14 of the 16 CPUs: ~ 1 hour
    # Intel Core i5-2520M (2.5 GHz x 4) Ubuntu laptop using 3 of the 4 cores: ~ 4 hours

#############
#############

def tc_mcs(mol1,mol2,key):
    # get maximum common substructure instance
    mcs = rdFMCS.FindMCS([mol1,mol2],timeout=10) # adding a 10 second timeout
    
    # get number of common bonds
    mcs_bonds = mcs.numBonds
    
    # get number of bonds for each
    # default is only heavy atom bonds
    mol1_bonds = mol1.GetNumBonds()
    mol2_bonds = mol2.GetNumBonds()
    
    # compute MCS-based Tanimoto
    tan_mcs = mcs_bonds / (mol1_bonds + mol2_bonds - mcs_bonds)
    return key, tan_mcs

# create a list of mol1, mol2, and their dictionary key as tuples
mol_tuples = []
for key, value in subsets.items():
    mol_tuples.append((value['mol1'],value['mol2'], key))

# run multiprocessing on the tc_mcs function
from multiprocessing import Pool

if __name__ == '__main__':
    with Pool(num_cpus) as p: # In our case, num_cpus = 14
        star_map = p.starmap(tc_mcs, mol_tuples)
    for key, tan_mcs in star_map:
        subsets[key].update({"tan_mcs": round(tan_mcs,3)})

# %%
list(subsets.values())[0:5]
# Out:
# [{'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119dee0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119df50>,
#   'tan_similarity': 0.382,
#   'tan_mcs': 0.444},
#  {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'CC3(C)c1ccccc1c2ccccc23',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119dfc0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e9d0>,
#   'tan_similarity': 0.186,
#   'tan_mcs': 0.588},
#  {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'CCCCCCc1cccc(CCCCCC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119d150>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119d460>,
#   'tan_similarity': 0.361,
#   'tan_mcs': 0.4},
#  {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'CCCc1cccc(CCC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119d380>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e030>,
#   'tan_similarity': 0.431,
#   'tan_mcs': 0.571},
#  {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'CCc1cccc(CC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e0a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e110>,
#   'tan_similarity': 0.5,
#   'tan_mcs': 0.667}]

# %%
# Keys are integers
list(subsets.keys())[0:5]
# Out:
# [0, 1, 2, 3, 4]

# %%
# Here is what the star_map variable looks like
star_map[0:5]
# Out:
# [(0, 0.4444444444444444),
#  (1, 0.5882352941176471),
#  (2, 0.4),
#  (3, 0.5714285714285714),
#  (4, 0.6666666666666666)]

# %% [markdown]
# # 6. Save Data

# %% [markdown]
# Save the data, so you don't have to re-compute the tanimoto and MCS similarity again.

# %%
# Save the subsets data as a pickle
import pickle
with open('subsets_cata.pickle', 'wb') as outfile:
    pickle.dump(subsets, outfile, pickle.HIGHEST_PROTOCOL)

# %%
# Save the node data
with open('node_data_cata.pickle', 'wb') as outfile:
    pickle.dump(node_data, outfile, pickle.HIGHEST_PROTOCOL)

# %%
subsets
# Out:
# {0: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119dee0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119df50>,
#   'tan_similarity': 0.382,
#   'tan_mcs': 0.444},
#  1: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'CC3(C)c1ccccc1c2ccccc23',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119dfc0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e9d0>,
#   'tan_similarity': 0.186,
#   'tan_mcs': 0.588},
#  2: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'CCCCCCc1cccc(CCCCCC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119d150>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119d460>,
#   'tan_similarity': 0.361,
#   'tan_mcs': 0.4},
#  3: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'CCCc1cccc(CCC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119d380>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e030>,
#   'tan_similarity': 0.431,
#   'tan_mcs': 0.571},
#  4: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'CCc1cccc(CC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e0a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e110>,
#   'tan_similarity': 0.5,
#   'tan_mcs': 0.667},
#  5: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e180>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e1f0>,
#   'tan_similarity': 0.138,
#   'tan_mcs': 0.409},
#  6: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e260>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e2d0>,
#   'tan_similarity': 0.201,
#   'tan_mcs': 0.409},
#  7: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'Cc1cc(C)ccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e340>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e3b0>,
#   'tan_similarity': 0.351,
#   'tan_mcs': 0.636},
#  8: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'Cc1cccc(C)c1C',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e420>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e490>,
#   'tan_similarity': 0.295,
#   'tan_mcs': 0.583},
#  9: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'Cc1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e500>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e570>,
#   'tan_similarity': 0.381,
#   'tan_mcs': 0.7},
#  10: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e5e0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e650>,
#   'tan_similarity': 0.14,
#   'tan_mcs': 0.286},
#  11: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e6c0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e730>,
#   'tan_similarity': 0.226,
#   'tan_mcs': 0.333},
#  12: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e7a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e880>,
#   'tan_similarity': 0.22,
#   'tan_mcs': 0.412},
#  13: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e8f0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119e960>,
#   'tan_similarity': 0.072,
#   'tan_mcs': 0.273},
#  14: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119ea40>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119eab0>,
#   'tan_similarity': 0.077,
#   'tan_mcs': 0.375},
#  15: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119eb20>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119eb90>,
#   'tan_similarity': 0.102,
#   'tan_mcs': 0.615},
#  16: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119ec00>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119ec70>,
#   'tan_similarity': 0.124,
#   'tan_mcs': 0.6},
#  17: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119ece0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119ed50>,
#   'tan_similarity': 0.102,
#   'tan_mcs': 0.615},
#  18: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119edc0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119ee30>,
#   'tan_similarity': 0.083,
#   'tan_mcs': 0.643},
#  19: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119eea0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119ef10>,
#   'tan_similarity': 0.102,
#   'tan_mcs': 0.529},
#  20: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119ef80>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119eff0>,
#   'tan_similarity': 0.15,
#   'tan_mcs': 0.526},
#  21: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f060>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f0d0>,
#   'tan_similarity': 0.145,
#   'tan_mcs': 0.5},
#  22: {'smi1': 'CC(C)(C)c1ccccc1',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f140>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f1b0>,
#   'tan_similarity': 0.102,
#   'tan_mcs': 0.409},
#  23: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'CC3(C)c1ccccc1c2ccccc23',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f220>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f290>,
#   'tan_similarity': 0.165,
#   'tan_mcs': 0.737},
#  24: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'CCCCCCc1cccc(CCCCCC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f300>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f370>,
#   'tan_similarity': 0.835,
#   'tan_mcs': 0.7},
#  25: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'CCCc1cccc(CCC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f3e0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f450>,
#   'tan_similarity': 0.819,
#   'tan_mcs': 0.75},
#  26: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'CCc1cccc(CC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f4c0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f530>,
#   'tan_similarity': 0.638,
#   'tan_mcs': 0.625},
#  27: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f5a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f610>,
#   'tan_similarity': 0.215,
#   'tan_mcs': 0.682},
#  28: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f680>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f6f0>,
#   'tan_similarity': 0.26,
#   'tan_mcs': 0.682},
#  29: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'Cc1cc(C)ccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f760>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f7d0>,
#   'tan_similarity': 0.356,
#   'tan_mcs': 0.5},
#  30: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'Cc1cccc(C)c1C',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f840>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f8b0>,
#   'tan_similarity': 0.312,
#   'tan_mcs': 0.471},
#  31: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'Cc1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f920>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119f990>,
#   'tan_similarity': 0.248,
#   'tan_mcs': 0.438},
#  32: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119fa00>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119fa70>,
#   'tan_similarity': 0.261,
#   'tan_mcs': 0.4},
#  33: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119fae0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119fb50>,
#   'tan_similarity': 0.245,
#   'tan_mcs': 0.312},
#  34: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119fbc0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119fc30>,
#   'tan_similarity': 0.239,
#   'tan_mcs': 0.364},
#  35: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119fca0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119fd10>,
#   'tan_similarity': 0.07,
#   'tan_mcs': 0.214},
#  36: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119fd80>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119fdf0>,
#   'tan_similarity': 0.069,
#   'tan_mcs': 0.273},
#  37: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119fe60>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119fed0>,
#   'tan_similarity': 0.084,
#   'tan_mcs': 0.588},
#  38: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e9119ff40>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4040>,
#   'tan_similarity': 0.081,
#   'tan_mcs': 0.375},
#  39: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c40b0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4120>,
#   'tan_similarity': 0.084,
#   'tan_mcs': 0.588},
#  40: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4190>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4200>,
#   'tan_similarity': 0.073,
#   'tan_mcs': 0.611},
#  41: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4270>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c42e0>,
#   'tan_similarity': 0.086,
#   'tan_mcs': 0.778},
#  42: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4350>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c43c0>,
#   'tan_similarity': 0.188,
#   'tan_mcs': 0.667},
#  43: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4430>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c44a0>,
#   'tan_similarity': 0.183,
#   'tan_mcs': 0.636},
#  44: {'smi1': 'CC(C)CCc1cccc(CCC(C)C)c1',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4510>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4580>,
#   'tan_similarity': 0.086,
#   'tan_mcs': 0.609},
#  45: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'CCCCCCc1cccc(CCCCCC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c45f0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4660>,
#   'tan_similarity': 0.166,
#   'tan_mcs': 0.591},
#  46: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'CCCc1cccc(CCC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c46d0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4740>,
#   'tan_similarity': 0.155,
#   'tan_mcs': 0.611},
#  47: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'CCc1cccc(CC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c47b0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4820>,
#   'tan_similarity': 0.147,
#   'tan_mcs': 0.5},
#  48: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4890>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4900>,
#   'tan_similarity': 0.396,
#   'tan_mcs': 0.652},
#  49: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4970>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c49e0>,
#   'tan_similarity': 0.117,
#   'tan_mcs': 0.652},
#  50: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'Cc1cc(C)ccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4a50>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4ac0>,
#   'tan_similarity': 0.094,
#   'tan_mcs': 0.389},
#  51: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'Cc1cccc(C)c1C',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4b30>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4ba0>,
#   'tan_similarity': 0.094,
#   'tan_mcs': 0.444},
#  52: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'Cc1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4c10>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4c80>,
#   'tan_similarity': 0.081,
#   'tan_mcs': 0.412},
#  53: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4cf0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4d60>,
#   'tan_similarity': 0.177,
#   'tan_mcs': 0.344},
#  54: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4dd0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4e40>,
#   'tan_similarity': 0.212,
#   'tan_mcs': 0.303},
#  55: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4eb0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4f20>,
#   'tan_similarity': 0.116,
#   'tan_mcs': 0.292},
#  56: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c4f90>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5000>,
#   'tan_similarity': 0.066,
#   'tan_mcs': 0.207},
#  57: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5070>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c50e0>,
#   'tan_similarity': 0.053,
#   'tan_mcs': 0.261},
#  58: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5150>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c51c0>,
#   'tan_similarity': 0.041,
#   'tan_mcs': 0.556},
#  59: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5230>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c52a0>,
#   'tan_similarity': 0.026,
#   'tan_mcs': 0.353},
#  60: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5310>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5380>,
#   'tan_similarity': 0.041,
#   'tan_mcs': 0.556},
#  61: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c53f0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5460>,
#   'tan_similarity': 0.157,
#   'tan_mcs': 0.765},
#  62: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c54d0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5540>,
#   'tan_similarity': 0.049,
#   'tan_mcs': 0.833},
#  63: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c55b0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5620>,
#   'tan_similarity': 0.804,
#   'tan_mcs': 0.895},
#  64: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5690>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5700>,
#   'tan_similarity': 0.77,
#   'tan_mcs': 0.85},
#  65: {'smi1': 'CC3(C)c1ccccc1c2ccccc23',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5770>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c57e0>,
#   'tan_similarity': 0.049,
#   'tan_mcs': 0.727},
#  66: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'CCCc1cccc(CCC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5850>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c58c0>,
#   'tan_similarity': 0.803,
#   'tan_mcs': 0.667},
#  67: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'CCc1cccc(CC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5930>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c59a0>,
#   'tan_similarity': 0.625,
#   'tan_mcs': 0.556},
#  68: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5a10>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5a80>,
#   'tan_similarity': 0.214,
#   'tan_mcs': 0.773},
#  69: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5af0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5b60>,
#   'tan_similarity': 0.256,
#   'tan_mcs': 0.773},
#  70: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'Cc1cc(C)ccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5bd0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5c40>,
#   'tan_similarity': 0.349,
#   'tan_mcs': 0.444},
#  71: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'Cc1cccc(C)c1C',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5cb0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5d20>,
#   'tan_similarity': 0.306,
#   'tan_mcs': 0.421},
#  72: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'Cc1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5d90>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5e00>,
#   'tan_similarity': 0.243,
#   'tan_mcs': 0.389},
#  73: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5e70>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5ee0>,
#   'tan_similarity': 0.255,
#   'tan_mcs': 0.375},
#  74: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5f50>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c5fc0>,
#   'tan_similarity': 0.249,
#   'tan_mcs': 0.294},
#  75: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6030>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c60a0>,
#   'tan_similarity': 0.236,
#   'tan_mcs': 0.333},
#  76: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6110>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6180>,
#   'tan_similarity': 0.066,
#   'tan_mcs': 0.2},
#  77: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c61f0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6260>,
#   'tan_similarity': 0.069,
#   'tan_mcs': 0.25},
#  78: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c62d0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6340>,
#   'tan_similarity': 0.083,
#   'tan_mcs': 0.526},
#  79: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c63b0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6420>,
#   'tan_similarity': 0.079,
#   'tan_mcs': 0.333},
#  80: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6490>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6500>,
#   'tan_similarity': 0.083,
#   'tan_mcs': 0.526},
#  81: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6570>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c65e0>,
#   'tan_similarity': 0.072,
#   'tan_mcs': 0.632},
#  82: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6650>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c66c0>,
#   'tan_similarity': 0.09,
#   'tan_mcs': 0.7},
#  83: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6730>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c67a0>,
#   'tan_similarity': 0.191,
#   'tan_mcs': 0.682},
#  84: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6810>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6880>,
#   'tan_similarity': 0.197,
#   'tan_mcs': 0.727},
#  85: {'smi1': 'CCCCCCc1cccc(CCCCCC)c1',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c68f0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6960>,
#   'tan_similarity': 0.09,
#   'tan_mcs': 0.696},
#  86: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'CCc1cccc(CC)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c69d0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6a40>,
#   'tan_similarity': 0.779,
#   'tan_mcs': 0.833},
#  87: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6ab0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6b20>,
#   'tan_similarity': 0.205,
#   'tan_mcs': 0.571},
#  88: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6b90>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6c00>,
#   'tan_similarity': 0.275,
#   'tan_mcs': 0.571},
#  89: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'Cc1cc(C)ccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6c70>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6ce0>,
#   'tan_similarity': 0.434,
#   'tan_mcs': 0.667},
#  90: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'Cc1cccc(C)c1C',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6d50>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6dc0>,
#   'tan_similarity': 0.371,
#   'tan_mcs': 0.615},
#  91: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'Cc1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6e30>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6ea0>,
#   'tan_similarity': 0.303,
#   'tan_mcs': 0.583},
#  92: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6f10>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6f80>,
#   'tan_similarity': 0.257,
#   'tan_mcs': 0.462},
#  93: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c6ff0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7060>,
#   'tan_similarity': 0.258,
#   'tan_mcs': 0.357},
#  94: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c70d0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7140>,
#   'tan_similarity': 0.265,
#   'tan_mcs': 0.444},
#  95: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c71b0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7220>,
#   'tan_similarity': 0.065,
#   'tan_mcs': 0.25},
#  96: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7290>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7300>,
#   'tan_similarity': 0.068,
#   'tan_mcs': 0.333},
#  97: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7370>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c73e0>,
#   'tan_similarity': 0.099,
#   'tan_mcs': 0.643},
#  98: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7450>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c74c0>,
#   'tan_similarity': 0.098,
#   'tan_mcs': 0.5},
#  99: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7530>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c75a0>,
#   'tan_similarity': 0.099,
#   'tan_mcs': 0.643},
#  100: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7610>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7680>,
#   'tan_similarity': 0.072,
#   'tan_mcs': 0.667},
#  101: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c76f0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7760>,
#   'tan_similarity': 0.1,
#   'tan_mcs': 0.75},
#  102: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c77d0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7840>,
#   'tan_similarity': 0.163,
#   'tan_mcs': 0.55},
#  103: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c78b0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7920>,
#   'tan_similarity': 0.156,
#   'tan_mcs': 0.524},
#  104: {'smi1': 'CCCc1cccc(CCC)c1',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7990>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7a00>,
#   'tan_similarity': 0.1,
#   'tan_mcs': 0.571},
#  105: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7a70>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7ae0>,
#   'tan_similarity': 0.201,
#   'tan_mcs': 0.476},
#  106: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7b50>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7bc0>,
#   'tan_similarity': 0.302,
#   'tan_mcs': 0.476},
#  107: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'Cc1cc(C)ccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7c30>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7ca0>,
#   'tan_similarity': 0.558,
#   'tan_mcs': 0.8},
#  108: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'Cc1cccc(C)c1C',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7d10>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7d80>,
#   'tan_similarity': 0.457,
#   'tan_mcs': 0.727},
#  109: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'Cc1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7df0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7e60>,
#   'tan_similarity': 0.389,
#   'tan_mcs': 0.7},
#  110: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7ed0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c7f40>,
#   'tan_similarity': 0.2,
#   'tan_mcs': 0.385},
#  111: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8040>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c80b0>,
#   'tan_similarity': 0.257,
#   'tan_mcs': 0.385},
#  112: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8120>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8190>,
#   'tan_similarity': 0.305,
#   'tan_mcs': 0.5},
#  113: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8200>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8270>,
#   'tan_similarity': 0.068,
#   'tan_mcs': 0.273},
#  114: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c82e0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8350>,
#   'tan_similarity': 0.072,
#   'tan_mcs': 0.375},
#  115: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c83c0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8430>,
#   'tan_similarity': 0.103,
#   'tan_mcs': 0.75},
#  116: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c84a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8510>,
#   'tan_similarity': 0.126,
#   'tan_mcs': 0.6},
#  117: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8580>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c85f0>,
#   'tan_similarity': 0.103,
#   'tan_mcs': 0.75},
#  118: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8660>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c86d0>,
#   'tan_similarity': 0.084,
#   'tan_mcs': 0.643},
#  119: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8740>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c87b0>,
#   'tan_similarity': 0.104,
#   'tan_mcs': 0.625},
#  120: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8820>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8890>,
#   'tan_similarity': 0.125,
#   'tan_mcs': 0.45},
#  121: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8900>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8970>,
#   'tan_similarity': 0.12,
#   'tan_mcs': 0.429},
#  122: {'smi1': 'CCc1cccc(CC)c1',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c89e0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8a50>,
#   'tan_similarity': 0.104,
#   'tan_mcs': 0.476},
#  123: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8ac0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8b30>,
#   'tan_similarity': 0.129,
#   'tan_mcs': 1.0},
#  124: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'Cc1cc(C)ccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8ba0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8c10>,
#   'tan_similarity': 0.112,
#   'tan_mcs': 0.381},
#  125: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'Cc1cccc(C)c1C',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8c80>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8cf0>,
#   'tan_similarity': 0.147,
#   'tan_mcs': 0.429},
#  126: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'Cc1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8d60>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8dd0>,
#   'tan_similarity': 0.078,
#   'tan_mcs': 0.333},
#  127: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8e40>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8eb0>,
#   'tan_similarity': 0.229,
#   'tan_mcs': 0.343},
#  128: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8f20>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c8f90>,
#   'tan_similarity': 0.226,
#   'tan_mcs': 0.343},
#  129: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9000>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9070>,
#   'tan_similarity': 0.13,
#   'tan_mcs': 0.296},
#  130: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c90e0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9150>,
#   'tan_similarity': 0.083,
#   'tan_mcs': 0.182},
#  131: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c91c0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9230>,
#   'tan_similarity': 0.069,
#   'tan_mcs': 0.222},
#  132: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c92a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9310>,
#   'tan_similarity': 0.036,
#   'tan_mcs': 0.524},
#  133: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9380>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c93f0>,
#   'tan_similarity': 0.025,
#   'tan_mcs': 0.286},
#  134: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9460>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c94d0>,
#   'tan_similarity': 0.036,
#   'tan_mcs': 0.524},
#  135: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9540>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c95b0>,
#   'tan_similarity': 0.153,
#   'tan_mcs': 0.619},
#  136: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9620>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9690>,
#   'tan_similarity': 0.04,
#   'tan_mcs': 0.762},
#  137: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9700>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9770>,
#   'tan_similarity': 0.363,
#   'tan_mcs': 0.667},
#  138: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c97e0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9850>,
#   'tan_similarity': 0.354,
#   'tan_mcs': 0.708},
#  139: {'smi1': 'Cc1cc(C)c2CCc4cccc3CCc1c2c34',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c98c0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9930>,
#   'tan_similarity': 0.04,
#   'tan_mcs': 0.75},
#  140: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'Cc1cc(C)ccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c99a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9a10>,
#   'tan_similarity': 0.373,
#   'tan_mcs': 0.381},
#  141: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'Cc1cccc(C)c1C',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9a80>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9af0>,
#   'tan_similarity': 0.333,
#   'tan_mcs': 0.429},
#  142: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'Cc1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9b60>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9bd0>,
#   'tan_similarity': 0.261,
#   'tan_mcs': 0.333},
#  143: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9c40>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9cb0>,
#   'tan_similarity': 0.126,
#   'tan_mcs': 0.343},
#  144: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9d20>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9d90>,
#   'tan_similarity': 0.145,
#   'tan_mcs': 0.343},
#  145: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9e00>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9e70>,
#   'tan_similarity': 0.247,
#   'tan_mcs': 0.296},
#  146: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9ee0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9f50>,
#   'tan_similarity': 0.08,
#   'tan_mcs': 0.182},
#  147: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911c9fc0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca030>,
#   'tan_similarity': 0.071,
#   'tan_mcs': 0.222},
#  148: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca0a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca110>,
#   'tan_similarity': 0.31,
#   'tan_mcs': 0.524},
#  149: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca180>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca1f0>,
#   'tan_similarity': 0.085,
#   'tan_mcs': 0.286},
#  150: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca260>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca2d0>,
#   'tan_similarity': 0.31,
#   'tan_mcs': 0.524},
#  151: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca340>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca3b0>,
#   'tan_similarity': 0.103,
#   'tan_mcs': 0.619},
#  152: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca420>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca490>,
#   'tan_similarity': 0.38,
#   'tan_mcs': 0.762},
#  153: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca500>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca570>,
#   'tan_similarity': 0.112,
#   'tan_mcs': 0.667},
#  154: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca5e0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca650>,
#   'tan_similarity': 0.11,
#   'tan_mcs': 0.708},
#  155: {'smi1': 'Cc1cc(C)c2ccc4cccc3ccc1c2c34',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca6c0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca730>,
#   'tan_similarity': 0.38,
#   'tan_mcs': 0.75},
#  156: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'Cc1cccc(C)c1C',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca7a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca810>,
#   'tan_similarity': 0.716,
#   'tan_mcs': 0.889},
#  157: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'Cc1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca880>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca8f0>,
#   'tan_similarity': 0.698,
#   'tan_mcs': 0.875},
#  158: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca960>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ca9d0>,
#   'tan_similarity': 0.112,
#   'tan_mcs': 0.308},
#  159: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911caa40>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911caab0>,
#   'tan_similarity': 0.143,
#   'tan_mcs': 0.308},
#  160: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cab20>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cab90>,
#   'tan_similarity': 0.39,
#   'tan_mcs': 0.571},
#  161: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cac00>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cac70>,
#   'tan_similarity': 0.072,
#   'tan_mcs': 0.3},
#  162: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cace0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cad50>,
#   'tan_similarity': 0.078,
#   'tan_mcs': 0.429},
#  163: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cadc0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cae30>,
#   'tan_similarity': 0.155,
#   'tan_mcs': 0.583},
#  164: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911caea0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911caf10>,
#   'tan_similarity': 0.226,
#   'tan_mcs': 0.75},
#  165: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911caf80>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911caff0>,
#   'tan_similarity': 0.155,
#   'tan_mcs': 0.583},
#  166: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb060>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb0d0>,
#   'tan_similarity': 0.116,
#   'tan_mcs': 0.5},
#  167: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb140>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb1b0>,
#   'tan_similarity': 0.138,
#   'tan_mcs': 0.5},
#  168: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb220>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb290>,
#   'tan_similarity': 0.076,
#   'tan_mcs': 0.35},
#  169: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb300>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb370>,
#   'tan_similarity': 0.073,
#   'tan_mcs': 0.333},
#  170: {'smi1': 'Cc1cc(C)ccc1',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb3e0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb450>,
#   'tan_similarity': 0.138,
#   'tan_mcs': 0.381},
#  171: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'Cc1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb4c0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb530>,
#   'tan_similarity': 0.5,
#   'tan_mcs': 0.778},
#  172: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb5a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb610>,
#   'tan_similarity': 0.118,
#   'tan_mcs': 0.296},
#  173: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb680>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb6f0>,
#   'tan_similarity': 0.144,
#   'tan_mcs': 0.296},
#  174: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb760>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb7d0>,
#   'tan_similarity': 0.346,
#   'tan_mcs': 0.533},
#  175: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb840>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb8b0>,
#   'tan_similarity': 0.07,
#   'tan_mcs': 0.286},
#  176: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb920>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cb990>,
#   'tan_similarity': 0.075,
#   'tan_mcs': 0.4},
#  177: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cba00>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cba70>,
#   'tan_similarity': 0.135,
#   'tan_mcs': 0.667},
#  178: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cbae0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cbb50>,
#   'tan_similarity': 0.162,
#   'tan_mcs': 0.667},
#  179: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cbbc0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cbc30>,
#   'tan_similarity': 0.135,
#   'tan_mcs': 0.667},
#  180: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cbca0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cbd10>,
#   'tan_similarity': 0.106,
#   'tan_mcs': 0.571},
#  181: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cbd80>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cbdf0>,
#   'tan_similarity': 0.123,
#   'tan_mcs': 0.562},
#  182: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cbe60>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cbed0>,
#   'tan_similarity': 0.082,
#   'tan_mcs': 0.4},
#  183: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cbf40>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc040>,
#   'tan_similarity': 0.077,
#   'tan_mcs': 0.381},
#  184: {'smi1': 'Cc1cccc(C)c1C',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc0b0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc120>,
#   'tan_similarity': 0.123,
#   'tan_mcs': 0.429},
#  185: {'smi1': 'Cc1ccccc1',
#   'smi2': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc190>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc200>,
#   'tan_similarity': 0.078,
#   'tan_mcs': 0.269},
#  186: {'smi1': 'Cc1ccccc1',
#   'smi2': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc270>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc2e0>,
#   'tan_similarity': 0.1,
#   'tan_mcs': 0.269},
#  187: {'smi1': 'Cc1ccccc1',
#   'smi2': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc350>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc3c0>,
#   'tan_similarity': 0.272,
#   'tan_mcs': 0.5},
#  188: {'smi1': 'Cc1ccccc1',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc430>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc4a0>,
#   'tan_similarity': 0.078,
#   'tan_mcs': 0.316},
#  189: {'smi1': 'Cc1ccccc1',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc510>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc580>,
#   'tan_similarity': 0.087,
#   'tan_mcs': 0.462},
#  190: {'smi1': 'Cc1ccccc1',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc5f0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc660>,
#   'tan_similarity': 0.191,
#   'tan_mcs': 0.636},
#  191: {'smi1': 'Cc1ccccc1',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc6d0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc740>,
#   'tan_similarity': 0.324,
#   'tan_mcs': 0.857},
#  192: {'smi1': 'Cc1ccccc1',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc7b0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc820>,
#   'tan_similarity': 0.191,
#   'tan_mcs': 0.636},
#  193: {'smi1': 'Cc1ccccc1',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc890>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc900>,
#   'tan_similarity': 0.124,
#   'tan_mcs': 0.538},
#  194: {'smi1': 'Cc1ccccc1',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc970>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cc9e0>,
#   'tan_similarity': 0.167,
#   'tan_mcs': 0.438},
#  195: {'smi1': 'Cc1ccccc1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cca50>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ccac0>,
#   'tan_similarity': 0.065,
#   'tan_mcs': 0.368},
#  196: {'smi1': 'Cc1ccccc1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ccb30>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ccba0>,
#   'tan_similarity': 0.062,
#   'tan_mcs': 0.35},
#  197: {'smi1': 'Cc1ccccc1',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ccc10>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ccc80>,
#   'tan_similarity': 0.167,
#   'tan_mcs': 0.333},
#  198: {'smi1': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'smi2': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cccf0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ccd60>,
#   'tan_similarity': 0.518,
#   'tan_mcs': 0.444},
#  199: {'smi1': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'smi2': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ccdd0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cce40>,
#   'tan_similarity': 0.26,
#   'tan_mcs': 0.429},
#  200: {'smi1': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cceb0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ccf20>,
#   'tan_similarity': 0.079,
#   'tan_mcs': 0.158},
#  201: {'smi1': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ccf90>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd000>,
#   'tan_similarity': 0.065,
#   'tan_mcs': 0.188},
#  202: {'smi1': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd070>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e9119d4d0>,
#   'tan_similarity': 0.036,
#   'tan_mcs': 0.321},
#  203: {'smi1': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd0e0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd150>,
#   'tan_similarity': 0.025,
#   'tan_mcs': 0.231},
#  204: {'smi1': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd1c0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd230>,
#   'tan_similarity': 0.036,
#   'tan_mcs': 0.321},
#  205: {'smi1': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd2a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd310>,
#   'tan_similarity': 0.05,
#   'tan_mcs': 0.345},
#  206: {'smi1': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd380>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd3f0>,
#   'tan_similarity': 0.041,
#   'tan_mcs': 0.4},
#  207: {'smi1': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd460>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd4d0>,
#   'tan_similarity': 0.207,
# ...
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd540>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd5b0>,
#   'tan_similarity': 0.205,
#   'tan_mcs': 0.314},
#  209: {'smi1': 'FC(F)(F)C(F)(F)C(F)(F)c1cccc(C(F)(F)C(F)(F)C(F)(F)F)c1',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd620>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd690>,
#   'tan_similarity': 0.041,
#   'tan_mcs': 0.343},
#  210: {'smi1': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'smi2': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd700>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd770>,
#   'tan_similarity': 0.256,
#   'tan_mcs': 0.481},
#  211: {'smi1': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd7e0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd850>,
#   'tan_similarity': 0.08,
#   'tan_mcs': 0.158},
#  212: {'smi1': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd8c0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd930>,
#   'tan_similarity': 0.062,
#   'tan_mcs': 0.188},
#  213: {'smi1': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cd9a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cda10>,
#   'tan_similarity': 0.043,
#   'tan_mcs': 0.321},
#  214: {'smi1': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cda80>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cdaf0>,
#   'tan_similarity': 0.032,
#   'tan_mcs': 0.231},
#  215: {'smi1': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cdb60>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cdbd0>,
#   'tan_similarity': 0.043,
#   'tan_mcs': 0.321},
#  216: {'smi1': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cdc40>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cdcb0>,
#   'tan_similarity': 0.06,
#   'tan_mcs': 0.3},
#  217: {'smi1': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cdd20>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cdd90>,
#   'tan_similarity': 0.05,
#   'tan_mcs': 0.312},
#  218: {'smi1': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cde00>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cde70>,
#   'tan_similarity': 0.21,
#   'tan_mcs': 0.286},
#  219: {'smi1': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cdee0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cdf50>,
#   'tan_similarity': 0.211,
#   'tan_mcs': 0.278},
#  220: {'smi1': 'FC(F)(F)C(F)(c1cccc(C(F)(C(F)(F)F)C(F)(F)F)c1)C(F)(F)F',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cdfc0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce030>,
#   'tan_similarity': 0.05,
#   'tan_mcs': 0.27},
#  221: {'smi1': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'smi2': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce0a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce110>,
#   'tan_similarity': 0.081,
#   'tan_mcs': 0.231},
#  222: {'smi1': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce180>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce1f0>,
#   'tan_similarity': 0.078,
#   'tan_mcs': 0.3},
#  223: {'smi1': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce260>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce2d0>,
#   'tan_similarity': 0.084,
#   'tan_mcs': 0.389},
#  224: {'smi1': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce340>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce3b0>,
#   'tan_similarity': 0.088,
#   'tan_mcs': 0.429},
#  225: {'smi1': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce420>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce490>,
#   'tan_similarity': 0.084,
#   'tan_mcs': 0.389},
#  226: {'smi1': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce500>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce570>,
#   'tan_similarity': 0.112,
#   'tan_mcs': 0.35},
#  227: {'smi1': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce5e0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce650>,
#   'tan_similarity': 0.086,
#   'tan_mcs': 0.364},
#  228: {'smi1': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce6c0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce730>,
#   'tan_similarity': 0.103,
#   'tan_mcs': 0.269},
#  229: {'smi1': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce7a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce810>,
#   'tan_similarity': 0.097,
#   'tan_mcs': 0.259},
#  230: {'smi1': 'FC(F)(F)c1cccc(C(F)(F)F)c1',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce880>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce8f0>,
#   'tan_similarity': 0.086,
#   'tan_mcs': 0.296},
#  231: {'smi1': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'smi2': 'FS(F)(F)(F)(F)c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce960>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ce9d0>,
#   'tan_similarity': 0.724,
#   'tan_mcs': 0.667},
#  232: {'smi1': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cea40>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ceab0>,
#   'tan_similarity': 0.081,
#   'tan_mcs': 0.261},
#  233: {'smi1': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ceb20>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ceb90>,
#   'tan_similarity': 0.077,
#   'tan_mcs': 0.333},
#  234: {'smi1': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cec00>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cec70>,
#   'tan_similarity': 0.081,
#   'tan_mcs': 0.261},
#  235: {'smi1': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cece0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ced50>,
#   'tan_similarity': 0.075,
#   'tan_mcs': 0.24},
#  236: {'smi1': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cedc0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cee30>,
#   'tan_similarity': 0.082,
#   'tan_mcs': 0.214},
#  237: {'smi1': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911ceea0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cef10>,
#   'tan_similarity': 0.066,
#   'tan_mcs': 0.194},
#  238: {'smi1': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cef80>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911ceff0>,
#   'tan_similarity': 0.065,
#   'tan_mcs': 0.188},
#  239: {'smi1': 'FS(F)(F)(F)(F)c1cccc(S(F)(F)(F)(F)F)c1',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf060>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf0d0>,
#   'tan_similarity': 0.082,
#   'tan_mcs': 0.182},
#  240: {'smi1': 'FS(F)(F)(F)(F)c1ccccc1',
#   'smi2': 'c1cccc2ccccc12',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf140>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf1b0>,
#   'tan_similarity': 0.098,
#   'tan_mcs': 0.353},
#  241: {'smi1': 'FS(F)(F)(F)(F)c1ccccc1',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf220>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf290>,
#   'tan_similarity': 0.106,
#   'tan_mcs': 0.5},
#  242: {'smi1': 'FS(F)(F)(F)(F)c1ccccc1',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf300>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf370>,
#   'tan_similarity': 0.098,
#   'tan_mcs': 0.353},
#  243: {'smi1': 'FS(F)(F)(F)(F)c1ccccc1',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf3e0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf450>,
#   'tan_similarity': 0.088,
#   'tan_mcs': 0.316},
#  244: {'smi1': 'FS(F)(F)(F)(F)c1ccccc1',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf4c0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf530>,
#   'tan_similarity': 0.099,
#   'tan_mcs': 0.273},
#  245: {'smi1': 'FS(F)(F)(F)(F)c1ccccc1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf5a0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf610>,
#   'tan_similarity': 0.054,
#   'tan_mcs': 0.24},
#  246: {'smi1': 'FS(F)(F)(F)(F)c1ccccc1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf680>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf6f0>,
#   'tan_similarity': 0.052,
#   'tan_mcs': 0.231},
#  247: {'smi1': 'FS(F)(F)(F)(F)c1ccccc1',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf760>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf7d0>,
#   'tan_similarity': 0.099,
#   'tan_mcs': 0.222},
#  248: {'smi1': 'c1cccc2ccccc12',
#   'smi2': 'c1ccccc1',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf840>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf8b0>,
#   'tan_similarity': 0.273,
#   'tan_mcs': 0.545},
#  249: {'smi1': 'c1cccc2ccccc12',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf920>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cf990>,
#   'tan_similarity': 1.0,
#   'tan_mcs': 1.0},
#  250: {'smi1': 'c1cccc2ccccc12',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cfa00>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cfa70>,
#   'tan_similarity': 0.137,
#   'tan_mcs': 0.714},
#  251: {'smi1': 'c1cccc2ccccc12',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cfae0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cfb50>,
#   'tan_similarity': 0.815,
#   'tan_mcs': 0.688},
#  252: {'smi1': 'c1cccc2ccccc12',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cfbc0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cfc30>,
#   'tan_similarity': 0.039,
#   'tan_mcs': 0.5},
#  253: {'smi1': 'c1cccc2ccccc12',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cfca0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cfd10>,
#   'tan_similarity': 0.037,
#   'tan_mcs': 0.476},
#  254: {'smi1': 'c1cccc2ccccc12',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cfd80>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cfdf0>,
#   'tan_similarity': 0.815,
#   'tan_mcs': 0.524},
#  255: {'smi1': 'c1ccccc1',
#   'smi2': 'c2ccc1ccccc1c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cfe60>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911cfed0>,
#   'tan_similarity': 0.273,
#   'tan_mcs': 0.545},
#  256: {'smi1': 'c1ccccc1',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911cff40>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0040>,
#   'tan_similarity': 0.167,
#   'tan_mcs': 0.462},
#  257: {'smi1': 'c1ccccc1',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d00b0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0120>,
#   'tan_similarity': 0.222,
#   'tan_mcs': 0.375},
#  258: {'smi1': 'c1ccccc1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0190>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0200>,
#   'tan_similarity': 0.021,
#   'tan_mcs': 0.316},
#  259: {'smi1': 'c1ccccc1',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0270>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d02e0>,
#   'tan_similarity': 0.02,
#   'tan_mcs': 0.3},
#  260: {'smi1': 'c1ccccc1',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0350>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d03c0>,
#   'tan_similarity': 0.222,
#   'tan_mcs': 0.286},
#  261: {'smi1': 'c2ccc1ccccc1c2',
#   'smi2': 'c2cccc(c1ccccc1)c2',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0430>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d04a0>,
#   'tan_similarity': 0.137,
#   'tan_mcs': 0.714},
#  262: {'smi1': 'c2ccc1ccccc1c2',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0510>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0580>,
#   'tan_similarity': 0.815,
#   'tan_mcs': 0.688},
#  263: {'smi1': 'c2ccc1ccccc1c2',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d05f0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0660>,
#   'tan_similarity': 0.039,
#   'tan_mcs': 0.5},
#  264: {'smi1': 'c2ccc1ccccc1c2',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d06d0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0740>,
#   'tan_similarity': 0.037,
#   'tan_mcs': 0.476},
#  265: {'smi1': 'c2ccc1ccccc1c2',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d07b0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0820>,
#   'tan_similarity': 0.815,
#   'tan_mcs': 0.524},
#  266: {'smi1': 'c2cccc(c1ccccc1)c2',
#   'smi2': 'c3ccc2ccc1ccccc1c2c3',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0890>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0900>,
#   'tan_similarity': 0.125,
#   'tan_mcs': 0.812},
#  267: {'smi1': 'c2cccc(c1ccccc1)c2',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0970>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d09e0>,
#   'tan_similarity': 0.126,
#   'tan_mcs': 0.684},
#  268: {'smi1': 'c2cccc(c1ccccc1)c2',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0a50>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0ac0>,
#   'tan_similarity': 0.121,
#   'tan_mcs': 0.65},
#  269: {'smi1': 'c2cccc(c1ccccc1)c2',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0b30>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0ba0>,
#   'tan_similarity': 0.125,
#   'tan_mcs': 0.619},
#  270: {'smi1': 'c3ccc2ccc1ccccc1c2c3',
#   'smi2': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0c10>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0c80>,
#   'tan_similarity': 0.047,
#   'tan_mcs': 0.75},
#  271: {'smi1': 'c3ccc2ccc1ccccc1c2c3',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0cf0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0d60>,
#   'tan_similarity': 0.047,
#   'tan_mcs': 0.714},
#  272: {'smi1': 'c3ccc2ccc1ccccc1c2c3',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0dd0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0e40>,
#   'tan_similarity': 1.0,
#   'tan_mcs': 0.762},
#  273: {'smi1': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'smi2': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0eb0>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0f20>,
#   'tan_similarity': 0.923,
#   'tan_mcs': 0.857},
#  274: {'smi1': 'c4ccc3c1ccccc1C2(CCC2)c3c4',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d0f90>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d1000>,
#   'tan_similarity': 0.047,
#   'tan_mcs': 0.739},
#  275: {'smi1': 'c4ccc3c1ccccc1C2(CCCC2)c3c4',
#   'smi2': 'c4ccc3c1ccccc1c2ccccc2c3c4',
#   'mol1': <rdkit.Chem.rdchem.Mol at 0x7f1e911d1070>,
#   'mol2': <rdkit.Chem.rdchem.Mol at 0x7f1e911d10e0>,
#   'tan_similarity': 0.047,
#   'tan_mcs': 0.783}}

# %%
mean_ee_nuc = df.groupby(['3,3â€™ Catalyst Substituent ','nucleophile SMILES'])['ee'].mean()
mean_ee_ele = df.groupby(['3,3â€™ Catalyst Substituent ','electrophile SMILES'])['ee'].mean()

# %%
mean_ee_nuc['CC(C)(C)c1ccccc1']
# Out:
# nucleophile SMILES
# C/C(=C\CCCCCl)C(=O)/C=C/C(C)C            0.831315
# C/C(=C\CCc1ccccc1)C(=O)/C=C/C(C)C        0.819915
# C/C=C(C)/C(=O)/C=C/C(C)(C)C              0.842640
# C/C=C(C)/C(=O)/C=C/C(C)C                 0.836371
# C/C=C(C)/C=C/CCO                         0.850077
# C1=CCC=C1                                0.838227
# C1=CCCC=C1                               0.861372
# C=C(/C=C/C(C)(C)C)C(C)(C)C               0.831474
# C=C(/C=C/c1ccccc1)O[Si](C)(C)C(C)(C)C    0.835625
# C=C(C)/C=C(C)/C                          0.842165
# C=C(C)/C=C/C                             0.819481
# C=C(C)/C=C/CCOCc1ccccc1                  0.841064
# C=C(C)C(=C)C                             0.850839
# C=C(OC)O[Si](C)(C)C                      0.851807
# C=C(OC)O[Si](C)(C)C(C)(C)C               0.872003
# C=C(OC)O[Si](CC)(CC)CC                   0.853280
# C=C(OC)O[Si]1(C(C)C)C(C)CC1C             0.808796
# C=C(OC1CCCCC1)O[Si](C)(C)C(C)(C)C        0.825969
# C=C(OCc1ccccc1)O[Si](C)(C)C              0.827597
# C=C(OCc1ccccc1)O[Si](C)(C)C(C)(C)C       0.834469
# C=C(O[Si](C)(C)C(C)(C)C)c1ccccc1         0.804196
# C=C/C=C(OC(C)C)\O[Si](C)(C)C(C)(C)C      0.841902
# C=C/C=C/C                                0.808035
# C=C/C=C/C1CCCCC1                         0.856016
# C=C/C=C/CCCCCC                           0.838536
# C=C1C=C(O[Si](C)(C)C)OC(C)(C)O1          0.842656
# C=CC(=C)C                                0.848382
# C=CC(=C)CC/C=C(C)\C                      0.812588
# C=CC[Si](C)(C)C                          0.853398
# C=CO[Si](C)(C)C(C)(C)C                   0.851942
# C=CO[Si](CC)(CC)CC                       0.832023
# CC/C=C(C)/C(=O)/C=C/C(C)C                0.834069
# CC/C=C(C)/C(=O)/C=C/C(CC)CC              0.839707
# CC/C=C(C)/C(=O)/C=C/C1CC1                0.806856
# CC/C=C(C)/C(=O)/C=C/C1CCC1               0.843628
# CC/C=C(C)/C(=O)/C=C/C1CCCC1              0.819974
# CC/C=C(C)/C(=O)/C=C/C1CCCCC1             0.846430
# CC/C=C(C)/C(=O)/C=C/CC(C)C               0.826900
# CC/C=C(C)/C(=O)/C=C/CCC                  0.838820
# CC/C=C(C)/C(=O)/C=C/c1ccccc1Br           0.797623
# CCCCC/C=C(C)/C(=O)/C=C/C(C)C             0.835832
# CO/C(=C/c1ccccc1)O[Si](C)(C)C            0.841619
# CO/C(=C\C(C)C)O[Si](C)(C)C               0.849025
# CO/C(=C\c1ccccc1)O[Si](C)(C)C            0.839514
# CO/C(O[Si](C)(C)C)=C(C)/C                0.821724
# CO/C(O[Si](C)(C)C)=C/1CCC1               0.832297
# CO/C(O[Si](C)(C)C)=C/1CCCC1              0.836910
# CO/C(O[Si](C)(C)C)=C/1CCCCC1             0.838658
# Name: ee, dtype: float64

# %%
nuc_tuples = []
ele_tuples = []

cats = np.unique(df['3,3â€™ Catalyst Substituent '])
nucs = np.unique(df['nucleophile SMILES'])
eles = np.unique(df['electrophile SMILES'])


for cat in cats:
    for i in range(len(nucs)):
        nuc_tuples.append((cat,nucs[i], mean_ee_nuc[cat][i]))
for cat in cats:
    for i in range(len(eles)):
        ele_tuples.append((cat,eles[i], mean_ee_ele[cat][i]))


with open('subsets_cata_nuc.pickle', 'wb') as outfile:
    pickle.dump(nuc_tuples, outfile, pickle.HIGHEST_PROTOCOL)
with open('subsets_cata_ele.pickle', 'wb') as outfile:
    pickle.dump(ele_tuples, outfile, pickle.HIGHEST_PROTOCOL)
